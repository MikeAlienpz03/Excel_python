# %% [markdown]
#  First-class functions
#
#  * Las funciones en Python son objetos de primera clase. Los teóricos del lenguaje de programación definen un "objeto de primera clase" como una entidad de programa que puede ser:
#
#  - creada en tiempo de ejecución;
#  - asignada a una variable o elemento en una estructura de datos;
#  - pasar como argumento a una función;
#  - ser devuelta como resultado de una función.
#
# * Los enteros, las cadenas y los diccionarios son otros ejemplos de objetos de primera clase en Python. Pero, si llegaste a Python desde un lenguaje donde las funciones no son
# ciudadanos de primera clase, este capítulo y el resto de la Parte III del libro se centran en las implicaciones y aplicaciones prácticas de tratar las funciones como objetos.

# %% [markdown]
# **Tratar una función como un objeto**
#
# * La siguiente sesión de consola muestra que las funciones de Python son objetos. Aquí creamos una función, la llamamos, leemos su atributo __doc__, y comprobamos que el propio objeto función es
#  una instancia de la clase function:

# %% [markdown]
# Se usa operador ternario para el if
#
# valor_si_verdadero if condición else valor_si_falso

# %%
def factorial(n):
    if n < 2:
        return 1
    else:
        return n * factorial(n-1)

# %%
def factorial(n):
    """Returns n!!"""
    return 1 if n < 2 else n * factorial(n-1)

# %%
#5!=5×4×3×2×1
factorial(5)
# Out:
# 120

# %%
factorial(3)
# Out:
# 6

# %%
factorial.__doc__
# Out:
# 'Returns n!!'

# %% [markdown]
# Pasamos la funcion como argumento

# %%
fac = factorial
list(map(fac,range(6)))
# Out:
# [1, 1, 2, 6, 24, 120]

# %% [markdown]
# Higher-order functions
#
# * Una función que toma una función como argumento o devuelve una función como resultado es una función de orden superior.

# %%
fruits = ['strawberry', 'fig', 'apple', 'cherry', 'raspberry', 'banana']
sorted(fruits,key=len)
# Out:
# ['fig', 'apple', 'cherry', 'banana', 'raspberry', 'strawberry']

# %%
def reversed(word):
    return word[::-1]


reversed("Testing")
# Out:
# 'gnitseT'

# %%
sorted(fruits,key=reversed)
# Out:
# ['banana', 'apple', 'fig', 'raspberry', 'strawberry', 'cherry']

# %% [markdown]
# **Design patterns with first-class functions**
#
# * **Caso práctico: refactorización de Strategy**
#
# * Strategy es un buen ejemplo de un patrón de diseño que puede ser más sencillo en Python si se aprovechan las funciones como objetos de primera clase. En la siguiente sección describimos e implementamos estrategia utilizando la estructura "clásica" descrita en el libro Patrones de diseño. Si estás familiarizado con el patrón clásico, puedes saltar a "Estrategia orientada a funciones" en la página 172, donde refactorizamos el código usando funciones, reduciendo significativamente el número de líneas.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# pag 169
